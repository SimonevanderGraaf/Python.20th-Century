# %% [markdown]
# # 1.7 Network graph visualization
# ## Table of Contents:
# ### 1. Installing libraries
# ### 2. Importing libraries and relationship data
# ### 3. Creating a network graph
# ### 4. Graph visualization with Pyvis
# ### 5. Community detection - Leiden algorithm
# ### 6. The most important countries in the 20th century
# #### - 01 Degree
# #### - 02 Closeness
# #### - 03 Betweenness

# %% [markdown]
# ### 1. Installing libraries

# %%
pip install pyvis==0.3.1
# Out:
# Collecting pyvis==0.3.1
#   Downloading pyvis-0.3.1.tar.gz (748 kB)
#      ---------------------------------------- 0.0/748.9 kB ? eta -:--:--
#       --------------------------------------- 10.2/748.9 kB ? eta -:--:--
#      - ----------------------------------- 30.7/748.9 kB 262.6 kB/s eta 0:00:03
#      --- --------------------------------- 71.7/748.9 kB 491.5 kB/s eta 0:00:02
#      ---- -------------------------------- 92.2/748.9 kB 655.4 kB/s eta 0:00:02
#      -------------- ----------------------- 276.5/748.9 kB 1.2 MB/s eta 0:00:01
#      ------------------------------ ------- 593.9/748.9 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 748.9/748.9 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from pyvis==0.3.1) (3.1.4)
# Requirement already satisfied: networkx>=1.11 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from pyvis==0.3.1) (2.8.8)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from pyvis==0.3.1) (8.20.0)
# Collecting jsonpickle>=1.4.1 (from pyvis==0.3.1)
#   Downloading jsonpickle-3.2.1-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: decorator in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from ipython>=5.3.0->pyvis==0.3.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from ipython>=5.3.0->pyvis==0.3.1) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from ipython>=5.3.0->pyvis==0.3.1) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from ipython>=5.3.0->pyvis==0.3.1) (5.7.1)
# Requirement already satisfied: colorama in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from jinja2>=2.9.6->pyvis==0.3.1) (2.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.3.1) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis==0.3.1) (0.2.5)
# Requirement already satisfied: executing in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (0.2.2)
# Requirement already satisfied: six in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis==0.3.1) (1.16.0)
# Downloading jsonpickle-3.2.1-py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB ? eta 0:00:00
# Building wheels for collected packages: pyvis
#   Building wheel for pyvis (setup.py): started
#   Building wheel for pyvis (setup.py): finished with status 'done'
#   Created wheel for pyvis: filename=pyvis-0.3.1-py3-none-any.whl size=755848 sha256=9fd6e0c9670105188ef47e1ad8a10fda29abee3df639ce1fc110b7e9fda5be65
#   Stored in directory: c:\users\svand\appdata\local\pip\cache\wheels\83\76\b0\8be6263eaa807c52b432b8e4d8eb2629d21b856215ae6d7024
# Successfully built pyvis
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-3.2.1 pyvis-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn==0.12.1
# Out:
# Requirement already satisfied: seaborn==0.12.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from seaborn==0.12.1) (1.25.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from seaborn==0.12.1) (1.5.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from seaborn==0.12.1) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from pandas>=0.25->seaborn==0.12.1) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn==0.12.1) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cdlib
# Out:
# Collecting cdlib
#   Downloading cdlib-0.4.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from cdlib) (1.25.2)
# Collecting scikit-learn (from cdlib)
#   Downloading scikit_learn-1.5.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: tqdm in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from cdlib) (4.66.4)
# Collecting networkx>=3.0 (from cdlib)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting demon (from cdlib)
#   Downloading demon-2.0.6-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-louvain>=0.16 (from cdlib)
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ---------------------------------------- 0.0/204.6 kB ? eta -:--:--
#      --------------- ----------------------- 81.9/204.6 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 204.6/204.6 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scipy>=1.10 (from cdlib)
#   Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 3.1 MB/s eta 0:00:00
# Collecting pulp (from cdlib)
#   Downloading PuLP-2.8.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: seaborn in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from cdlib) (0.12.1)
# Requirement already satisfied: pandas in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from cdlib) (1.5.1)
# Collecting eva-lcd (from cdlib)
#   Downloading eva_lcd-0.1.1-py3-none-any.whl.metadata (731 bytes)
# Collecting bimlpa (from cdlib)
#   Downloading bimlpa-0.1.2-py3-none-any.whl.metadata (725 bytes)
# Collecting python-igraph>=0.10 (from cdlib)
#   Downloading python_igraph-0.11.5-py3-none-any.whl.metadata (2.8 kB)
# Collecting angelcommunity (from cdlib)
#   Downloading angelcommunity-2.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pooch (from cdlib)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting dynetx (from cdlib)
#   Downloading dynetx-0.3.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting thresholdclustering (from cdlib)
#   Downloading thresholdclustering-1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting python-Levenshtein (from cdlib)
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting plotly (from cdlib)
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting igraph==0.11.5 (from python-igraph>=0.10->cdlib)
#   Downloading igraph-0.11.5-cp39-abi3-win_amd64.whl.metadata (3.9 kB)
# Collecting texttable>=1.6.2 (from igraph==0.11.5->python-igraph>=0.10->cdlib)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting future (from angelcommunity->cdlib)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: matplotlib in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from bimlpa->cdlib) (3.8.4)
# Requirement already satisfied: decorator in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from dynetx->cdlib) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from pandas->cdlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from pandas->cdlib) (2024.1)
# Collecting tenacity>=6.2.0 (from plotly->cdlib)
#   Downloading tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from plotly->cdlib) (23.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from pooch->cdlib) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from pooch->cdlib) (2.32.2)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein->cdlib)
#   Downloading Levenshtein-0.25.1-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein->cdlib)
#   Downloading rapidfuzz-3.9.3-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from scikit-learn->cdlib) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->cdlib)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from tqdm->cdlib) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib->bimlpa->cdlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib->bimlpa->cdlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib->bimlpa->cdlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib->bimlpa->cdlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib->bimlpa->cdlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from matplotlib->bimlpa->cdlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from python-dateutil>=2.8.1->pandas->cdlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from requests>=2.19.0->pooch->cdlib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from requests>=2.19.0->pooch->cdlib) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from requests>=2.19.0->pooch->cdlib) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from requests>=2.19.0->pooch->cdlib) (2024.6.2)
# Downloading cdlib-0.4.0-py3-none-any.whl (263 kB)
#    ---------------------------------------- 0.0/263.6 kB ? eta -:--:--
#    ------------------------------------- - 256.0/263.6 kB 16.4 MB/s eta 0:00:01
#    ------------------------------------- - 256.0/263.6 kB 16.4 MB/s eta 0:00:01
#    ---------------------------------------- 263.6/263.6 kB 2.3 MB/s eta 0:00:00
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------- -------------------------- 0.6/1.7 MB 12.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.9/1.7 MB 10.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 9.0 MB/s eta 0:00:00
# Downloading python_igraph-0.11.5-py3-none-any.whl (9.1 kB)
# Downloading igraph-0.11.5-cp39-abi3-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --------- ------------------------------ 0.4/1.5 MB 7.6 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 8.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.4/1.5 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 8.8 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.4/46.2 MB 13.2 MB/s eta 0:00:04
#     --------------------------------------- 0.9/46.2 MB 9.0 MB/s eta 0:00:06
#    - -------------------------------------- 1.3/46.2 MB 9.1 MB/s eta 0:00:05
#    - -------------------------------------- 1.9/46.2 MB 10.0 MB/s eta 0:00:05
#    -- ------------------------------------- 2.5/46.2 MB 10.8 MB/s eta 0:00:05
#    -- ------------------------------------- 3.2/46.2 MB 11.3 MB/s eta 0:00:04
#    --- ------------------------------------ 3.6/46.2 MB 10.8 MB/s eta 0:00:04
#    --- ------------------------------------ 4.1/46.2 MB 10.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/46.2 MB 11.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.2/46.2 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.6/46.2 MB 10.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.1/46.2 MB 11.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.7/46.2 MB 11.0 MB/s eta 0:00:04
#    ------ --------------------------------- 7.3/46.2 MB 11.1 MB/s eta 0:00:04
#    ------ --------------------------------- 7.8/46.2 MB 11.1 MB/s eta 0:00:04
#    ------- -------------------------------- 8.4/46.2 MB 11.2 MB/s eta 0:00:04
#    ------- -------------------------------- 8.9/46.2 MB 11.1 MB/s eta 0:00:04
#    -------- ------------------------------- 9.6/46.2 MB 11.4 MB/s eta 0:00:04
#    -------- ------------------------------- 10.0/46.2 MB 11.2 MB/s eta 0:00:04
#    --------- ------------------------------ 10.7/46.2 MB 11.7 MB/s eta 0:00:04
#    --------- ------------------------------ 11.2/46.2 MB 11.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 11.8/46.2 MB 11.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 12.5/46.2 MB 11.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 13.0/46.2 MB 11.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 13.6/46.2 MB 11.9 MB/s eta 0:00:03
#    ------------ --------------------------- 14.1/46.2 MB 11.7 MB/s eta 0:00:03
#    ------------ --------------------------- 14.6/46.2 MB 11.9 MB/s eta 0:00:03
#    ------------- -------------------------- 15.3/46.2 MB 11.9 MB/s eta 0:00:03
#    ------------- -------------------------- 15.5/46.2 MB 11.5 MB/s eta 0:00:03
#    ------------- -------------------------- 16.0/46.2 MB 11.7 MB/s eta 0:00:03
#    -------------- ------------------------- 16.7/46.2 MB 11.7 MB/s eta 0:00:03
#    -------------- ------------------------- 17.3/46.2 MB 11.9 MB/s eta 0:00:03
#    --------------- ------------------------ 17.9/46.2 MB 11.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.5/46.2 MB 11.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 19.3/46.2 MB 12.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.7/46.2 MB 11.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 20.4/46.2 MB 12.4 MB/s eta 0:00:03
#    ------------------ --------------------- 21.1/46.2 MB 12.6 MB/s eta 0:00:02
#    ------------------ --------------------- 21.5/46.2 MB 12.1 MB/s eta 0:00:03
#    ------------------- -------------------- 22.0/46.2 MB 12.1 MB/s eta 0:00:02
#    ------------------- -------------------- 22.8/46.2 MB 12.1 MB/s eta 0:00:02
#    -------------------- ------------------- 23.5/46.2 MB 12.1 MB/s eta 0:00:02
#    -------------------- ------------------- 23.5/46.2 MB 11.7 MB/s eta 0:00:02
#    -------------------- ------------------- 24.1/46.2 MB 11.9 MB/s eta 0:00:02
#    --------------------- ------------------ 24.8/46.2 MB 11.9 MB/s eta 0:00:02
#    --------------------- ------------------ 25.0/46.2 MB 11.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 25.6/46.2 MB 11.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 25.7/46.2 MB 11.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 26.5/46.2 MB 11.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 27.1/46.2 MB 11.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 27.7/46.2 MB 11.7 MB/s eta 0:00:02
#    ------------------------ --------------- 28.1/46.2 MB 11.7 MB/s eta 0:00:02
#    ------------------------ --------------- 28.2/46.2 MB 10.9 MB/s eta 0:00:02
#    ------------------------ --------------- 28.8/46.2 MB 10.9 MB/s eta 0:00:02
#    ------------------------- -------------- 29.3/46.2 MB 10.7 MB/s eta 0:00:02
#    ------------------------- -------------- 29.9/46.2 MB 10.9 MB/s eta 0:00:02
#    -------------------------- ------------- 30.5/46.2 MB 10.7 MB/s eta 0:00:02
#    --------------------------- ------------ 31.2/46.2 MB 10.7 MB/s eta 0:00:02
#    --------------------------- ------------ 31.7/46.2 MB 10.7 MB/s eta 0:00:02
#    --------------------------- ------------ 32.2/46.2 MB 10.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.8/46.2 MB 10.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 33.4/46.2 MB 10.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 34.1/46.2 MB 11.3 MB/s eta 0:00:02
#    ------------------------------ --------- 34.8/46.2 MB 11.3 MB/s eta 0:00:02
#    ------------------------------ --------- 35.6/46.2 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 36.0/46.2 MB 12.1 MB/s eta 0:00:01
#    ------------------------------- -------- 36.5/46.2 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 37.2/46.2 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 37.8/46.2 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 38.6/46.2 MB 12.8 MB/s eta 0:00:01
#    --------------------------------- ------ 39.0/46.2 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.6/46.2 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 40.2/46.2 MB 12.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.9/46.2 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ --- 41.6/46.2 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------ --- 42.0/46.2 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ --- 42.6/46.2 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------- -- 43.3/46.2 MB 13.4 MB/s eta 0:00:01
#    -------------------------------------- - 44.1/46.2 MB 13.6 MB/s eta 0:00:01
#    -------------------------------------- - 44.5/46.2 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  45.2/46.2 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  45.9/46.2 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 12.1 MB/s eta 0:00:00
# Downloading angelcommunity-2.0.0-py3-none-any.whl (10 kB)
# Downloading bimlpa-0.1.2-py3-none-any.whl (7.0 kB)
# Downloading demon-2.0.6-py3-none-any.whl (7.3 kB)
# Downloading dynetx-0.3.2-py3-none-any.whl (39 kB)
# Downloading eva_lcd-0.1.1-py3-none-any.whl (9.2 kB)
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.7/16.4 MB 20.8 MB/s eta 0:00:01
#    -- ------------------------------------- 1.1/16.4 MB 14.3 MB/s eta 0:00:02
#    --- ------------------------------------ 1.6/16.4 MB 12.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.2/16.4 MB 12.9 MB/s eta 0:00:02
#    ------- -------------------------------- 2.9/16.4 MB 13.1 MB/s eta 0:00:02
#    -------- ------------------------------- 3.5/16.4 MB 13.0 MB/s eta 0:00:01
#    --------- ------------------------------ 4.0/16.4 MB 12.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.7/16.4 MB 13.1 MB/s eta 0:00:01
#    ------------ --------------------------- 5.2/16.4 MB 12.9 MB/s eta 0:00:01
#    -------------- ------------------------- 5.8/16.4 MB 12.7 MB/s eta 0:00:01
#    --------------- ------------------------ 6.4/16.4 MB 12.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 7.0/16.4 MB 12.8 MB/s eta 0:00:01
#    ------------------ --------------------- 7.8/16.4 MB 13.0 MB/s eta 0:00:01
#    -------------------- ------------------- 8.4/16.4 MB 13.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.1/16.4 MB 13.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.7/16.4 MB 13.2 MB/s eta 0:00:01
#    ------------------------ --------------- 10.2/16.4 MB 13.1 MB/s eta 0:00:01
#    -------------------------- ------------- 10.9/16.4 MB 13.1 MB/s eta 0:00:01
#    --------------------------- ------------ 11.3/16.4 MB 12.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.9/16.4 MB 13.1 MB/s eta 0:00:01
#    ------------------------------ --------- 12.3/16.4 MB 12.8 MB/s eta 0:00:01
#    ------------------------------- -------- 12.9/16.4 MB 12.6 MB/s eta 0:00:01
#    -------------------------------- ------- 13.5/16.4 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.0/16.4 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.4 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------- -- 15.3/16.4 MB 12.6 MB/s eta 0:00:01
#    -------------------------------------- - 16.0/16.4 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------  16.4/16.4 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 12.3 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB ? eta 0:00:00
# Downloading PuLP-2.8.0-py3-none-any.whl (17.7 MB)
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    - -------------------------------------- 0.6/17.7 MB 18.8 MB/s eta 0:00:01
#    -- ------------------------------------- 1.3/17.7 MB 16.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.9/17.7 MB 15.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.4/17.7 MB 13.7 MB/s eta 0:00:02
#    ------ --------------------------------- 2.9/17.7 MB 13.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.7/17.7 MB 14.0 MB/s eta 0:00:01
#    --------- ------------------------------ 4.2/17.7 MB 13.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.9/17.7 MB 13.6 MB/s eta 0:00:01
#    ------------ --------------------------- 5.4/17.7 MB 13.2 MB/s eta 0:00:01
#    ------------- -------------------------- 5.9/17.7 MB 13.1 MB/s eta 0:00:01
#    -------------- ------------------------- 6.5/17.7 MB 12.9 MB/s eta 0:00:01
#    --------------- ------------------------ 7.0/17.7 MB 12.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 7.7/17.7 MB 13.0 MB/s eta 0:00:01
#    ------------------ --------------------- 8.2/17.7 MB 12.8 MB/s eta 0:00:01
#    -------------------- ------------------- 9.0/17.7 MB 13.0 MB/s eta 0:00:01
#    --------------------- ------------------ 9.4/17.7 MB 12.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 10.1/17.7 MB 12.9 MB/s eta 0:00:01
#    ------------------------ --------------- 10.6/17.7 MB 12.6 MB/s eta 0:00:01
#    ------------------------- -------------- 11.3/17.7 MB 12.6 MB/s eta 0:00:01
#    --------------------------- ------------ 12.1/17.7 MB 12.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 12.4/17.7 MB 12.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.9/17.7 MB 12.6 MB/s eta 0:00:01
#    ------------------------------ --------- 13.6/17.7 MB 12.4 MB/s eta 0:00:01
#    -------------------------------- ------- 14.2/17.7 MB 12.4 MB/s eta 0:00:01
#    --------------------------------- ------ 14.7/17.7 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.2/17.7 MB 12.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 15.7/17.7 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------- -- 16.5/17.7 MB 12.6 MB/s eta 0:00:01
#    -------------------------------------- - 17.2/17.7 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  17.6/17.7 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 17.7/17.7 MB 11.9 MB/s eta 0:00:00
# Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.1-cp311-cp311-win_amd64.whl (98 kB)
#    ---------------------------------------- 0.0/98.4 kB ? eta -:--:--
#    ---------------------------------------- 98.4/98.4 kB 2.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.0-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/11.0 MB 11.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.3/11.0 MB 13.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.9/11.0 MB 13.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.3/11.0 MB 12.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.0 MB 12.8 MB/s eta 0:00:01
#    ------------- -------------------------- 3.7/11.0 MB 13.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.1/11.0 MB 12.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/11.0 MB 12.5 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/11.0 MB 13.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.0 MB 12.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.5/11.0 MB 12.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/11.0 MB 12.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.7/11.0 MB 12.7 MB/s eta 0:00:01
#    ------------------------------ --------- 8.3/11.0 MB 12.6 MB/s eta 0:00:01
#    -------------------------------- ------- 9.0/11.0 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.6/11.0 MB 12.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 12.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 12.1 MB/s eta 0:00:00
# Downloading thresholdclustering-1.1-py3-none-any.whl (5.3 kB)
# Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    --------------------------------------- 491.3/491.3 kB 15.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.3-cp311-cp311-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.7/1.7 MB 15.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.7 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 13.1 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9403 sha256=ea879db6adfeefd0ccd16bd44630a76f864265872f451e2ac6a35a2fef37d25e
#   Stored in directory: c:\users\svand\appdata\local\pip\cache\wheels\11\c1\e7\f62a211c636275e2da798bf0c307a3ae79aeddaf2524a03ce4
# Successfully built python-louvain
# Installing collected packages: texttable, threadpoolctl, tenacity, scipy, rapidfuzz, pulp, networkx, igraph, future, thresholdclustering, scikit-learn, python-louvain, python-igraph, pooch, plotly, Levenshtein, eva-lcd, dynetx, demon, python-Levenshtein, bimlpa, angelcommunity, cdlib
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.8.8
#     Uninstalling networkx-2.8.8:
#       Successfully uninstalled networkx-2.8.8
# Successfully installed Levenshtein-0.25.1 angelcommunity-2.0.0 bimlpa-0.1.2 cdlib-0.4.0 demon-2.0.6 dynetx-0.3.2 eva-lcd-0.1.1 future-1.0.0 igraph-0.11.5 networkx-3.3 plotly-5.22.0 pooch-1.8.2 pulp-2.8.0 python-Levenshtein-0.25.1 python-igraph-0.11.5 python-louvain-0.16 rapidfuzz-3.9.3 scikit-learn-1.5.0 scipy-1.13.1 tenacity-8.3.0 texttable-1.7.0 threadpoolctl-3.5.0 thresholdclustering-1.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\svand\anaconda3\envs\twentieth_century\Lib\site-packages\~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\svand\anaconda3\envs\twentieth_century\Lib\site-packages\~cipy'.
#   You can safely remove it manually.

# %% [markdown]
# ### 2. Importing libraries and relationship data

# %%
import pandas as pd
import numpy as np
import networkx as nx
import os
import matplotlib.pyplot as plt
from pyvis.network import Network
import seaborn as sns
import pyvis

# %%
# Import relationship data

relationship_df = pd.read_csv('20th_century_relationships.csv', index_col = 0)

# %%
relationship_df
# Out:
#      source     target  value
# 0    france      italy     13
# 1     italy     russia      6
# 2   germany     russia     27
# 3   austria    germany     17
# 4   austria    hungary      6
# ..      ...        ...    ...
# 69  finland     russia      6
# 70    italy      japan      6
# 71  romania     russia      6
# 72    india    lebanon      1
# 73    india  singapore      5
#
# [74 rows x 3 columns]

# %% [markdown]
# ### 3. Creating a network graph

# %%
# Create a graph from a pandas dataframe

G = nx.from_pandas_edgelist(relationship_df, 
                            source = "source", 
                            target = "target", 
                            edge_attr = "value", 
                            create_using = nx.Graph())

# %%
h = plt.figure(figsize = (7,7))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, with_labels = True, node_color = 'red', edge_cmap = plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# ### 4. Graph visualization with Pyvis

# %%
# Define net object

net = Network()
net = Network(notebook = True,width="900px", height="800px", bgcolor='#222222', font_color='white')

# Define nodes from the G object
node_degree = dict(G.degree)

# Setting up node size attributes
nx.set_node_attributes(G, node_degree, 'size')
net.from_nx(G)
net.show_buttons(filter_ = True)
net.repulsion()
net.show("20thcentury.html")
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
#         <iframe
#             width="900px"
#             height="800px"
#             src="20thcentury.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 5. Community detection - Leiden algorithm

# %%
pip install igraph
# Out:
# Requirement already satisfied: igraph in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (0.11.5)
# Requirement already satisfied: texttable>=1.6.2 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from igraph) (1.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install leidenalg
# Out:
# Collecting leidenalg
#   Downloading leidenalg-0.10.2-cp38-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: igraph<0.12,>=0.10.0 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from leidenalg) (0.11.5)
# Requirement already satisfied: texttable>=1.6.2 in c:\users\svand\anaconda3\envs\twentieth_century\lib\site-packages (from igraph<0.12,>=0.10.0->leidenalg) (1.7.0)
# Downloading leidenalg-0.10.2-cp38-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.6 MB 2.0 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.6 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.1/1.6 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: leidenalg
# Successfully installed leidenalg-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from cdlib import algorithms
coms = algorithms.leiden(G)

# %%
type(coms)
# Out:
# cdlib.classes.node_clustering.NodeClustering

# %%
new_com = coms.to_node_community_map()

# %%
new_com
# Out:
# defaultdict(list,
#             {'france': [0],
#              'italy': [0],
#              'russia': [0],
#              'germany': [0],
#              'spain': [0],
#              'finland': [0],
#              'morocco': [0],
#              'algeria': [0],
#              'ukraine': [1],
#              'libya': [1],
#              'egypt': [1],
#              'iraq': [1],
#              'pakistan': [1],
#              'israel': [1],
#              'south africa': [1],
#              'iran': [1],
#              'estonia': [2],
#              'latvia': [2],
#              'lithuania': [2],
#              'laos': [2],
#              'cambodia': [2],
#              'kenya': [2],
#              'ghana': [2],
#              'japan': [3],
#              'thailand': [3],
#              'singapore': [3],
#              'solomon islands': [3],
#              'india': [3],
#              'lebanon': [3],
#              'austria': [4],
#              'hungary': [4],
#              'bulgaria': [4],
#              'poland': [4],
#              'albania': [4],
#              'romania': [4],
#              'mongolia': [5],
#              'cuba': [5],
#              'canada': [5],
#              'australia': [5],
#              'vietnam': [5],
#              'united states': [5],
#              'belgium': [6],
#              'netherlands': [6],
#              'luxembourg': [6],
#              'denmark': [6],
#              'norway': [6]})

# %%
# Put the output from new_com into a dictionary

dict_com = {k:v[0] for k,v in new_com.items()}

# %%
dict_com
# Out:
# {'france': 0,
#  'italy': 0,
#  'russia': 0,
#  'germany': 0,
#  'spain': 0,
#  'finland': 0,
#  'morocco': 0,
#  'algeria': 0,
#  'ukraine': 1,
#  'libya': 1,
#  'egypt': 1,
#  'iraq': 1,
#  'pakistan': 1,
#  'israel': 1,
#  'south africa': 1,
#  'iran': 1,
#  'estonia': 2,
#  'latvia': 2,
#  'lithuania': 2,
#  'laos': 2,
#  'cambodia': 2,
#  'kenya': 2,
#  'ghana': 2,
#  'japan': 3,
#  'thailand': 3,
#  'singapore': 3,
#  'solomon islands': 3,
#  'india': 3,
#  'lebanon': 3,
#  'austria': 4,
#  'hungary': 4,
#  'bulgaria': 4,
#  'poland': 4,
#  'albania': 4,
#  'romania': 4,
#  'mongolia': 5,
#  'cuba': 5,
#  'canada': 5,
#  'australia': 5,
#  'vietnam': 5,
#  'united states': 5,
#  'belgium': 6,
#  'netherlands': 6,
#  'luxembourg': 6,
#  'denmark': 6,
#  'norway': 6}

# %%
# Rerun network graph with the communities as an argument

nx.set_node_attributes(G, dict_com, 'group')
com_net = Network(notebook = True, width="1300px", height="700px", bgcolor='#222222', font_color='white')
com_net.from_nx(G)
com_net.show_buttons(filter_ = True)
com_net.repulsion()
com_net.show("20thcentury_communities_leiden.html")
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
#         <iframe
#             width="1300px"
#             height="700px"
#             src="20thcentury_communities_leiden.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### The Leiden algorithm shows more clear how the connections are devided. The wider connections of the countries linked to Germany are clearly the connections that are mentioned the most. But the colors show which other "groups" of connections there are. For example red shows the countries that in the story of the 20th century are mentioned in the same part of the story and are connected that way. and so are all countries of the same color mentioned together in a part of the text.

# %% [markdown]
# ### 6. The most important countries in the 20th century

# %% [markdown]
# #### 01 Degree centrality

# %%
degree_dict = nx.degree_centrality(G)
degree_dict
# Out:
# {'france': 0.17777777777777778,
#  'italy': 0.11111111111111112,
#  'russia': 0.17777777777777778,
#  'germany': 0.26666666666666666,
#  'austria': 0.044444444444444446,
#  'hungary': 0.08888888888888889,
#  'bulgaria': 0.08888888888888889,
#  'spain': 0.044444444444444446,
#  'poland': 0.11111111111111112,
#  'estonia': 0.06666666666666667,
#  'latvia': 0.06666666666666667,
#  'lithuania': 0.08888888888888889,
#  'finland': 0.06666666666666667,
#  'belgium': 0.08888888888888889,
#  'netherlands': 0.06666666666666667,
#  'luxembourg': 0.044444444444444446,
#  'denmark': 0.044444444444444446,
#  'norway': 0.044444444444444446,
#  'albania': 0.06666666666666667,
#  'ukraine': 0.044444444444444446,
#  'libya': 0.08888888888888889,
#  'egypt': 0.044444444444444446,
#  'iraq': 0.022222222222222223,
#  'japan': 0.17777777777777778,
#  'morocco': 0.044444444444444446,
#  'algeria': 0.044444444444444446,
#  'thailand': 0.044444444444444446,
#  'singapore': 0.06666666666666667,
#  'solomon islands': 0.022222222222222223,
#  'india': 0.11111111111111112,
#  'pakistan': 0.06666666666666667,
#  'israel': 0.06666666666666667,
#  'south africa': 0.022222222222222223,
#  'iran': 0.044444444444444446,
#  'laos': 0.044444444444444446,
#  'cambodia': 0.06666666666666667,
#  'kenya': 0.044444444444444446,
#  'ghana': 0.044444444444444446,
#  'romania': 0.06666666666666667,
#  'mongolia': 0.044444444444444446,
#  'cuba': 0.08888888888888889,
#  'canada': 0.044444444444444446,
#  'australia': 0.044444444444444446,
#  'vietnam': 0.06666666666666667,
#  'united states': 0.044444444444444446,
#  'lebanon': 0.022222222222222223}

# %%
degree_df = pd.DataFrame(degree_dict.items(), columns=['countries','centrality'])

# %%
degree_df
# Out:
#           countries  centrality
# 0            france    0.177778
# 1             italy    0.111111
# 2            russia    0.177778
# 3           germany    0.266667
# 4           austria    0.044444
# 5           hungary    0.088889
# 6          bulgaria    0.088889
# 7             spain    0.044444
# 8            poland    0.111111
# 9           estonia    0.066667
# 10           latvia    0.066667
# 11        lithuania    0.088889
# 12          finland    0.066667
# 13          belgium    0.088889
# 14      netherlands    0.066667
# 15       luxembourg    0.044444
# 16          denmark    0.044444
# 17           norway    0.044444
# 18          albania    0.066667
# 19          ukraine    0.044444
# 20            libya    0.088889
# 21            egypt    0.044444
# 22             iraq    0.022222
# 23            japan    0.177778
# 24          morocco    0.044444
# 25          algeria    0.044444
# 26         thailand    0.044444
# 27        singapore    0.066667
# 28  solomon islands    0.022222
# 29            india    0.111111
# 30         pakistan    0.066667
# 31           israel    0.066667
# 32     south africa    0.022222
# 33             iran    0.044444
# 34             laos    0.044444
# 35         cambodia    0.066667
# 36            kenya    0.044444
# 37            ghana    0.044444
# 38          romania    0.066667
# 39         mongolia    0.044444
# 40             cuba    0.088889
# 41           canada    0.044444
# 42        australia    0.044444
# 43          vietnam    0.066667
# 44    united states    0.044444
# 45          lebanon    0.022222

# %%
degree_df.sort_values(by = ['centrality'], ascending=False, inplace = True)

# %%
# Plot the degree centrality

plt.figure(figsize = (10, 10))
with sns.dark_palette("xkcd:blue", 22):
    sns.barplot(x = "centrality", y = "countries",
    saturation = 0.9, data = degree_df).set_title("20th Century - degree centrality")

# %% [markdown]
# ### Germany has the highest degree centrality, whic makes sense because from task 1.6 I already new it has the most connections. It is interesting to see to me that always multiple countries belong to the came degree centrality.

# %% [markdown]
# #### 02 Closeness centrality

# %%
closeness_dict = nx.closeness_centrality(G)
closeness_df = pd.DataFrame(closeness_dict.items(), columns=['countries','centrality'])

# %%
closeness_df.sort_values(by = ['centrality'], ascending=False, inplace = True)

# %%
plt.figure(figsize = (10, 10))
with sns.dark_palette("xkcd:blue", 22):
    sns.barplot(x = "centrality", y = "countries",
    saturation = 0.9, data = closeness_df).set_title("20th Century - closeness centrality")

# %% [markdown]
# #### Compared the the closeness centrality of Alice in Wonderland, the closeness of the countries mentioned in th 20th Century text is a lot lower. It makes sense because there are only a few countries connected to Germany which is the most mentioned country.

# %% [markdown]
# #### 03 Betweenness centrality

# %%
betweenness_dict = nx.betweenness_centrality(G)
betweennes_df = pd.DataFrame(betweenness_dict.items(), columns=['countries','centrality'])

# %%
betweennes_df.sort_values(by = ['centrality'], ascending=False, inplace = True)

# %%
plt.figure(figsize = (10, 10))
with sns.dark_palette("xkcd:blue", 22):
    sns.barplot(x = "centrality", y = "countries",
    saturation = 0.9, data = betweennes_df).set_title("20th Century - betweenness centrality")

# %% [markdown]
# ### Also in this measure Germany scores the highest and is by far the most influentual country of the text. Which makes sense because the text is mostly about the wars. Many countries score low as they are part of the story, but in specific smaller details.

# %%
# Save centrality measures
nx.set_node_attributes(G, degree_dict, 'degree_centrality')
nx.set_node_attributes(G, betweenness_dict, 'betweenness_centrality')
nx.set_node_attributes(G, closeness_dict, 'closeness_centrality')
